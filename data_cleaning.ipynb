# %%
import numpy as np
import pandas as pd

ds = pd.read_csv("./data/cleaned_sneaks.csv")

# %%
ds.isna().sum()
# Out:
# Unnamed: 0                0
# item                      0
# brand                     0
# retail                    0
# release                  90
# lowestAsk                 0
# numberOfAsks              0
# salesThisPeriod           0
# highestBid                0
# numberOfBids              0
# annualHigh                0
# annualLow                 0
# volatility                0
# deadstockSold             0
# pricePremium              0
# averageDeadstockPrice     0
# lastSale                  0
# changePercentage          0
# img_path                  0
# dtype: int64

# %%
# fix null release dates by taking the mode of each brand
ds["release"] = ds.groupby("brand")["release"].transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else "Unkown"))

# %%
# change date format and check for null dates
ds["release"] = pd.to_datetime(ds["release"], errors="coerce")
missing_dates = ds["release"].isna().sum()

print(f"missing dates: {missing_dates}")
ds.head()
# Out:
# missing dates: 0
#    Unnamed: 0                                     item   brand  retail  \
# 0           0             Jordan 4 Retro SB Pine Green  Jordan     225
# 1           1   Jordan 3 Retro White Cement Reimagined  Jordan     210
# 2           2  Nike Air Force 1 Low Tiffany & Co. 1837    Nike     400
# 3           3  Nike Air Max 1 '86 Big Bubble Sport Red    Nike     150
# 4           4                       MSCHF Big Red Boot   MSCHF     350
#
#      release  lowestAsk  numberOfAsks  salesThisPeriod  highestBid  \
# 0 2023-03-21        325          1995             2675         480
# 1 2023-03-11        190          2361             1289         280
# 2 2023-03-07        893          1310              282        1526
# 3 2023-03-26        177           704              240         200
# 4 2023-02-16        570           334               68         611
#
#    numberOfBids  annualHigh  annualLow  volatility  deadstockSold  \
# 0          3697         952        280    0.061347           5408
# 1          2597         757        150    0.115522          16894
# 2          2436        4831        705    0.232434           4711
# 3           366         550        150    0.095096            603
# 4           345        2445        498    0.186197            323
#
#    pricePremium  averageDeadstockPrice  lastSale  changePercentage  \
# 0         0.542                    388       347          0.000000
# 1         0.111                    297       234          0.016666
# 2         1.125                   1160       850         -0.132653
# 3         0.200                    228       180          0.000000
# 4         1.373                    883       831          0.037438
#
#                                             img_path
# 0          feetflix/Jordan 4 Retro SB Pine Green.jpg
# 1  feetflix/Jordan 3 Retro White Cement Reimagine...
# 2  feetflix/Nike Air Force 1 Low Tiffany & Co. 18...
# 3  feetflix/Nike Air Max 1 '86 Big Bubble Sport R...
# 4                    feetflix/MSCHF Big Red Boot.jpg

# %%
# feature extraction: dropping unused columns
ds.drop(columns=["Unnamed: 0", "numberOfAsks", "salesThisPeriod", "numberOfBids", "changePercentage"], inplace=True)

ds.head(10)
# Out:
#                                                 item        brand  retail  \
# 0                       Jordan 4 Retro SB Pine Green       Jordan     225
# 1             Jordan 3 Retro White Cement Reimagined       Jordan     210
# 2            Nike Air Force 1 Low Tiffany & Co. 1837         Nike     400
# 3            Nike Air Max 1 '86 Big Bubble Sport Red         Nike     150
# 4                                 MSCHF Big Red Boot        MSCHF     350
# 5           New Balance 990v6 Action Bronson Baklava  New Balance     220
# 6       Nike Dunk Low Retro White Black Panda (2021)         Nike     110
# 7  Nike Dunk Low Retro White Black Panda (2021) (...         Nike     100
# 8                             Nike Dunk Low Grey Fog         Nike     100
# 9  Nike Dunk Low Retro White Black Panda (2021) (GS)         Nike      85
#
#      release  lowestAsk  highestBid  annualHigh  annualLow  volatility  \
# 0 2023-03-21        325         480         952        280    0.061347
# 1 2023-03-11        190         280         757        150    0.115522
# 2 2023-03-07        893        1526        4831        705    0.232434
# 3 2023-03-26        177         200         550        150    0.095096
# 4 2023-02-16        570         611        2445        498    0.186197
# 5 2023-03-17        320         450         844        251    0.131970
# 6 2021-03-10        139         165         697          0    0.046333
# 7 2021-03-10        130         141         308        110    0.059427
# 8 2021-09-21        145         265         569        120    0.095350
# 9 2021-03-10        112         126         278         88    0.042461
#
#    deadstockSold  pricePremium  averageDeadstockPrice  lastSale  \
# 0           5408         0.542                    388       347
# 1          16894         0.111                    297       234
# 2           4711         1.125                   1160       850
# 3            603         0.200                    228       180
# 4            323         1.373                    883       831
# 5            281         0.586                    403       349
# 6         233962         0.318                    191       145
# 7         109763         0.440                    179       144
# 8          25651         0.690                    216       169
# 9          87660         0.529                    162       130
#
#                                             img_path
# 0          feetflix/Jordan 4 Retro SB Pine Green.jpg
# 1  feetflix/Jordan 3 Retro White Cement Reimagine...
# 2  feetflix/Nike Air Force 1 Low Tiffany & Co. 18...
# 3  feetflix/Nike Air Max 1 '86 Big Bubble Sport R...
# 4                    feetflix/MSCHF Big Red Boot.jpg
# 5  feetflix/New Balance 990v6 Action Bronson Bakl...
# 6  feetflix/Nike Dunk Low Retro White Black Panda...
# 7  feetflix/Nike Dunk Low Retro White Black Panda...
# 8                feetflix/Nike Dunk Low Grey Fog.jpg
# 9  feetflix/Nike Dunk Low Retro White Black Panda...

# %%
# found issue with duplicate brand name
ds[ds["brand"].isin(["ASICS", "Asics"])].head()
ds["brand"] = ds["brand"].replace({"Asics": "ASICS"})
ds[ds["brand"].isin(["ASICS"])].head()
# Out:
#                                                   item  brand  retail  \
# 563                   ASICS ACTIBREEZE 3D Sandal Black  ASICS      80
# 926         ASICS Gel-1130 Cream Pure Silver (Women's)  ASICS      70
# 929       ASICS Gel-Kayano 14 White Midnight (Women's)  ASICS     180
# 1433  ASICS Gel-Lyte III Sneaker Politics Always Ready  ASICS     150
# 1965    ASICS Gel-Lyte III AFEW Beauty of Imperfection  ASICS     170
#
#         release  lowestAsk  highestBid  annualHigh  annualLow  volatility  \
# 563  2022-07-21        117         140         375         80    0.144152
# 926  2022-07-21         78          90         219         78    0.111731
# 929  2022-07-21        145         255         381        110    0.273995
# 1433 2022-05-30        140         280         500        120    0.091679
# 1965 2022-02-26        110         185         570        101    0.123714
#
#       deadstockSold  pricePremium  averageDeadstockPrice  lastSale  \
# 563             544         0.938                    158       155
# 926             248         0.129                    121        79
# 929             133        -0.179                    192       148
# 1433            216         0.353                    195       203
# 1965            372        -0.353                    201       110
#
#                                                img_path
# 563       feetflix/ASICS ACTIBREEZE 3D Sandal Black.jpg
# 926   feetflix/ASICS Gel-1130 Cream Pure Silver (Wom...
# 929   feetflix/ASICS Gel-Kayano 14 White Midnight (W...
# 1433  feetflix/ASICS Gel-Lyte III Sneaker Politics A...
# 1965  feetflix/ASICS Gel-Lyte III AFEW Beauty of Imp...

# %%
# check for extremely large values
print(ds.describe().T[["min", "max"]])
print(ds.isna().sum())
# Out:
#                                        min                  max
# retail                                 0.0               1110.0
# release                2004-01-01 00:00:00  2023-04-22 00:00:00
# lowestAsk                             37.0               1804.0
# highestBid                            50.0               3167.0
# annualHigh                            83.0               6500.0
# annualLow                              0.0               1258.0
# volatility                             0.0             0.754551
# deadstockSold                         18.0             233962.0
# pricePremium                        -0.889               16.654
# averageDeadstockPrice                 50.0               2319.0
# lastSale                              36.0               2295.0
# item                     0
# brand                    0
# retail                   0
# release                  0
# lowestAsk                0
# highestBid               0
# annualHigh               0
# annualLow                0
# volatility               0
# deadstockSold            0
# pricePremium             6
# averageDeadstockPrice    0
# lastSale                 0
# img_path                 0
# dtype: int64

# %%
# replace inf values with NaN
ds.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
# fill in null values with median
ds["pricePremium"] = ds["pricePremium"].fillna(ds["pricePremium"].median())

# %%
def add_air_to_jordan(name):
    if "Jordan" in name and not name.startswith("Air Jordan"):
        return name.replace("Jordan", "Air Jordan", 1)
    return name

ds["item"] = ds["item"].apply(add_air_to_jordan)
ds.head()
# Out:
#                                          item   brand  retail     release  \
# 0            Air Jordan 4 Retro SB Pine Green  Jordan     225  2023-03-21
# 1  Air Jordan 3 Retro White Cement Reimagined  Jordan     210  2023-03-11
# 2     Nike Air Force 1 Low Tiffany & Co. 1837    Nike     400  2023-03-07
# 3     Nike Air Max 1 '86 Big Bubble Sport Red    Nike     150  2023-03-26
# 4                          MSCHF Big Red Boot   MSCHF     350  2023-02-16
#
#    lowestAsk  highestBid  annualHigh  annualLow  volatility  deadstockSold  \
# 0        325         480         952        280    0.061347           5408
# 1        190         280         757        150    0.115522          16894
# 2        893        1526        4831        705    0.232434           4711
# 3        177         200         550        150    0.095096            603
# 4        570         611        2445        498    0.186197            323
#
#    pricePremium  averageDeadstockPrice  lastSale  \
# 0         0.542                    388       347
# 1         0.111                    297       234
# 2         1.125                   1160       850
# 3         0.200                    228       180
# 4         1.373                    883       831
#
#                                             img_path
# 0          feetflix/Jordan 4 Retro SB Pine Green.jpg
# 1  feetflix/Jordan 3 Retro White Cement Reimagine...
# 2  feetflix/Nike Air Force 1 Low Tiffany & Co. 18...
# 3  feetflix/Nike Air Max 1 '86 Big Bubble Sport R...
# 4                    feetflix/MSCHF Big Red Boot.jpg

# %%
ds.to_csv("cleaned_sneaks.csv", index=False, mode="w")
